# %%
import pandas as pd

# %%
from matplotlib import pyplot as pt

# %%
sample_data = pd.read_csv('bank1.csv')

# %%
sample_data
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      56   technician  married    primary      no       63     yes   no
# 1      21       admin.  married   tertiary      no       79     yes   no
# 2      19   management  married  secondary      no     -288     yes  yes
# 3      84      unknown  married   tertiary      no     1279      no   no
# 4      35  blue-collar  married    primary      no       26     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4994   64      retired   single    primary      no        0     yes   no
# 4995   41  blue-collar  married   tertiary      no      275     yes   no
# 4996   51  blue-collar  married   tertiary      no      874     yes   no
# 4997   38   management  married   tertiary      no      247     yes  yes
# 4998   36   technician  married   tertiary      no     6606     yes   no
#
#         contact  day month  duration  campaign  OperatingSystems  Browser  \
# ...

# %%
pt.bar(sample_data['age'],sample_data['balance'])
pt.xlabel('AGE GROUP')
pt.ylabel('ACCOUNT BALANCE')
pt.title("BAR GRAPH")
pt.xticks(rotation = 45)
pt.show()

# %%
pt.bar(sample_data['job'],sample_data['balance'])
pt.xlabel('JOB-TYPE')
pt.ylabel('ACCOUNT BALANCE')
pt.title("BAR GRAPH2")
pt.xticks(rotation = 45)
pt.show()

# %%
pt.figure(figsize=(6,6))
pt.pie(sample_data['age'],labels=sample_data['balance'],autopct='%1.1f%%',startangle=140)
pt.title('Pie chart')
pt.show()

# %%
age = sample_data['age']
balance = sample_data['balance']
pt.plot(age,balance)
pt.xlabel('Age-GROUP')
pt.ylabel('ACCOUNT BALANCE')
pt.title('LINE CHART AGE/BALANCE')
pt.show()
